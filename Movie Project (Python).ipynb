# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# pd.set_option('display.max_rows', 8000)
# pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv(r'C:\Users\soura\Downloads\Alex - The Analyst\Projects\movies.csv')
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# ...

# %%
df.dtypes
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes       float64
# director     object
# writer       object
# star         object
# country      object
# budget      float64
# gross       float64
# company      object
# runtime     float64
# dtype: object

# %%
# Method #1: Budget col has a few NaN value so giving error with int64, so used Int64 ('I' capital) which accepts NaN values:
df['budget'] = df['budget'].astype('Int64') 
type(df['budget'][0])
# Out:
# numpy.int64

# %%
# Method #2: Filling NaN value with 0 before using int64
df.budget = df.budget.fillna(0)
df['budget'].astype('int64')
type(df['budget'][0])
# Out:
# numpy.int64

# %%
# Applying the same for 'gross' column using Method #1 i.e. Int()
# df.gross = df.gross.fillna(0)
df['budget'].astype('Int64')
type(df['budget'][0])
# Out:
# numpy.int64

# %%
df['votes'].isnull().mean()
# Out:
# 0.0003912363067292645

# %%
np.mean(df['votes'].isnull())
# Out:
# 0.0003912363067292645

# %%
# We need to see if we have any missing data
# Let's loop through the data and see if there is anything missing

for col in df.columns:
    perc_missing = df[col].isnull().mean()
    print(f'{col} - {round(perc_missing)*100}%')
# Out:
# name - 0%
# rating - 0%
# genre - 0%
# year - 0%
# released - 0%
# score - 0%
# votes - 0%
# director - 0%
# writer - 0%
# star - 0%
# country - 0%
# budget - 0%
# gross - 0%
# company - 0%
# runtime - 0%

# %%
for col in df.columns:
    pct_missing = np.mean(df[col].isnull())
    print('{} - {}%'.format(col, round(pct_missing*100)))

# %%
# correcting the year column
df.head(20)

# %%
# len(df.index)
for c in range(len(df.index)):

    if str(df['released'][c])== 'NaN':
        d = str(df['year'][c])
    else: 
        
        d= df['released'][c].split(' ')
    
    if len(str(d)) == 0:
        d = df['year'][c]
        print(c, df['released'][c],'\t', d[0])
    elif len(d) == 1:
        print(c, df['released'][c],'\t', d[0])
    elif len(d) == 2:
        print(c, df['released'][c],'\t',d[0])
    elif len(d) == 2:
        print(c, df['released'][c],'\t',d[1])
    elif len(d) == 3:
        print(c, df['released'][c],'\t',d[1])
    elif len(d) == 4:
        print(c, df['released'][c],'\t',d[2])
    else: print(c, df['released'][c],'\t',d[2])

# %%
d= df['released'][0].split(' ')
print(d[2])
df['year_corrected']=d[2]

# %%
# len(df.index)
#     if str(df['released'][c])== 'NaN':
#         d = str(df['year'][c])
#     else: 

#     d= df['released'][c].split(' ')
#     yc=''
for c in range(len(df.index)):
    if len(df['released'][c].split(' ')) == 0:
#         d = df['year'][c]
#         yc=d[0]
        df['year_corrected1']=df['year'][c]
    elif len(df['released'][c].split(' ')) == 1:
#         yc=d[0]
        df['year_corrected1']=df['released'][c].split(' ')[0]
    elif len(df['released'][c].split(' ')) == 2:
#         yc=d[0]
        df['year_corrected1']=df['released'][c].split(' ')[0]
    elif len(df['released'][c].split(' ')) == 2:
#         yc=d[1]
        df['year_corrected1']=df['released'][c].split(' ')[1]
    elif len(df['released'][c].split(' ')) == 3:
#         yc=d[1]
        df['year_corrected1']=df['released'][c].split(' ')[1]
    elif len(df['released'][c].split(' ')) == 4:
#         yc=d[2]
        df['year_corrected1']=df['released'][c].split(' ')[2]
    else: 
#         print(d[2])
        df['year_corrected1']=df['released'][c].split(' ')[2]

# %%
# a = str(df.released[5728])
# a
# df.released[312]='September 17, 1982 (Japan)'
# df.released[201].split(' ')
print(d)

# %%
# df.released[312]='September 17, 1982 (Japan)'
df.released[786]

# %%
d= df['released'][3].split(' ')
d

# %%
df.tail()

# %%
len(df.index)

# %%
# Find the rows with released = null values
df[df['released'].isna()]
# Out:
# Empty DataFrame
# Columns: [name, rating, genre, year, released, score, votes, director, writer, star, country, budget, gross, company, runtime]
# Index: []

# %%
df['released1'] =df.released.astype('str')

# %%
type(df.released[0])

# %%
df['released'][5728] = '2010'
df['released'][5730] = '2010'
# Out:
# C:\Users\soura\AppData\Local\Temp\ipykernel_30564\2719278655.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['released'][5728] = '2010'
# C:\Users\soura\AppData\Local\Temp\ipykernel_30564\2719278655.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['released'][5730] = '2010'

# %%
df['released'][5728]
# df['released'][5730]

# %%
# len(df.index)
for c in range(len(df.index)):
    
    if str(df['released'][c])== 'NaN':
        d = df['year'][c]
    else: 

        d= df['released'][c].split(' ')
    
    if len(str(d)) == 0:
        d = df['year'][c]
#         print(c, df['released'][c],'\t', d[0])
        df['year_corrected']=d[0]
    elif len(d) == 1:
#         print(c, df['released'][c],'\t', d[0])
        df['year_corrected']=d[0]
    elif len(d) == 2:
#         print(c, df['released'][c],'\t',d[0])
        df['year_corrected']=d[0]
#     elif len(d) == 2:
#         print(c, df['released'][c],'\t',d[1])
    elif len(d) == 3:
#         print(c, df['released'][c],'\t',d[1])
        df['year_corrected']=d[1]
    elif len(d) == 4:
#         print(c, df['released'][c],'\t',d[2])
        df['year_corrected']=d[2]
    else: #print(c, df['released'][c],'\t',d[2])
        df['year_corrected']=d[2]

# %%
df.head()

# %%
# Working Model
# c=1
# d= df['released'][c].split(' ')
# df['tt'][c]=d[2]

# %%
# Creating a blank column - To avoid 'Key error' for the below 
df['year_correct']=''

# %%
for c in range(len(df.index)):
    d= df['released'][c].split(' ')
    if len(d) == 0:
        d = df['year'][c]
        df['year_correct'][c]=d[0]
    elif len(d) == 1:
        df['year_correct'][c]=d[0]
    elif len(d) == 2:
        df['year_correct'][c]=d[0]
    elif len(d) == 3:
        df['year_correct'][c]=d[1]
    elif len(d) >= 4:
        df['year_correct'][c]=d[2]
# Out:
# C:\Users\soura\AppData\Local\Temp\ipykernel_30564\2830188666.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['year_correct'][c]=d[2]
# C:\Users\soura\AppData\Local\Temp\ipykernel_30564\2830188666.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['year_correct'][c]=d[1]
# C:\Users\soura\AppData\Local\Temp\ipykernel_30564\2830188666.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
df.year

# %%
# df.drop(['year_corrected','yr','year_correct','tt'],axis=1,inplace=True)
df

# %%
# We still find that some values (~20) are not correctly replaced
df.year_correct.sort_values()
# Out:
# 463     (United
# 1680    (United
# 1735    (United
# 2029    (United
# 1753    (United
#          ...
# 7604       2020
# 7462       2020
# 7584       2020
# 7650       2020
# 7667       2020
# Name: year_correct, Length: 7668, dtype: object

# %%
df['released'][1041].split(' ')

# %%
df['year_correct'][719]= df['released'][719].split(' ')[1]
df['year_correct'][1819]= df['released'][1819].split(' ')[1]
df['year_correct'][201]= df['released'][201].split(' ')[0]
df['year_correct'][1947]= df['released'][1947].split(' ')[1]
df['year_correct'][1041]= df['released'][1041].split(' ')[1]
# df['year_correct'][1680]= df['released'][1680].split(' ')[1]
# Out:
# C:\Users\soura\AppData\Local\Temp\ipykernel_30564\3256055695.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['year_correct'][719]= df['released'][719].split(' ')[1]
# C:\Users\soura\AppData\Local\Temp\ipykernel_30564\3256055695.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['year_correct'][1819]= df['released'][1819].split(' ')[1]
# C:\Users\soura\AppData\Local\Temp\ipykernel_30564\3256055695.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
df['released'][2525].split(' ')

# %%
df['released'][1819].split(' ')

# %%
for c in df.index:
    if df['year_correct'][c][0] == "(":
        d= df['released'][c].split(' ')
        print(d)
        if len(d) == 3:
            df['year_correct'][c]=d[0]
        elif len(d) >= 4:
            df['year_correct'][c]=d[1]
# Out:
# ['November', '1980', '(United', 'Kingdom)']
# ['October', '1982', '(United', 'States)']
# ['March', '1992', '(United', 'States)']
# ['January', '1983', '(United', 'Kingdom)']
# ['August', '1983', '(United', 'States)']
# ['February', '1984', '(United', 'States)']
# ['March', '1985', '(United', 'States)']
# ['March', '1986', '(United', 'States)']
# ['1985', '(United', 'States)']
# ['October', '1986', '(United', 'States)']
# ['February', '1987', '(United', 'States)']
# ['1987', '(United', 'States)']
# ['May', '1988', '(United', 'Kingdom)']
# ['September', '1987', '(United', 'States)']
# ['June', '1991', '(United', 'States)']
# ['May', '1989', '(United', 'States)']
# ['May', '1988', '(United', 'States)']
# ['August', '1988', '(United', 'States)']
# ['October', '1988', '(United', 'States)']
# ['October', '1988', '(United', 'States)']
# ['June', '1988', '(United', 'States)']
# ['March', '1989', '(United', 'States)']
# ['July', '1989', '(United', 'States)']
# ...

# %%
# for c in df.index:
#     i=1
#     if df['year_correct'][c][0]=="(":
#         print(i)
#         i = i+1

# %%
for c in df.index:
    if df['year_correct'][c][0] == "19":
        print(c)

# %%
df.year_correct
# Out:
# 0       1980
# 1       1980
# 2       1980
# 3       1980
# 4       1980
#         ...
# 7663    2020
# 7664    2020
# 7665    2020
# 7666    2020
# 7667    2020
# Name: year_correct, Length: 7668, dtype: object

# %%
df1 = df

# %%
df1.head()

# %%
df1.sort_values(by='gross', inplace=False, ascending=False)
# Out:
#                                             name rating   genre  year  \
# 5445                                      Avatar  PG-13  Action  2009
# 7445                           Avengers: Endgame  PG-13  Action  2019
# 3045                                     Titanic  PG-13   Drama  1997
# 6663  Star Wars: Episode VII - The Force Awakens  PG-13  Action  2015
# 7244                      Avengers: Infinity War  PG-13  Action  2018
# ...                                          ...    ...     ...   ...
# 7663                                More to Life    NaN   Drama  2020
# 7664                                 Dream Round    NaN  Comedy  2020
# 7665                               Saving Mbango    NaN   Drama  2020
# 7666                                It's Just Us    NaN   Drama  2020
# 7667                                   Tee em el    NaN  Horror  2020
#
#                                released  score      votes       director  \
# ...

# %%
# Getting rid of duplicate Company
df['company'].sort_values().count()
# Out:
# 7651

# %%
df['company'].drop_duplicates().sort_values().count()  # Gives the distinct values, drops duplicates
# Out:
# 2385

# %%
# Guess: Budget is High Correlation
plt.title('Budget Vs Gross Revenue')
sns.scatterplot(x='budget',y='gross',data=df1,)
# Out:
# <AxesSubplot:title={'center':'Budget Vs Gross Revenue'}, xlabel='budget', ylabel='gross'>

# %%
# Regression Plot
# sns.regplot(x='budget',y='gross',data=df1)


sns.regplot(x="gross", y="budget", data=df1, scatter_kws={'color':'orange'},line_kws={'color':'blue'}, marker='*')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_30564\1003224605.py in <module>
#       3
#       4
# ----> 5 sns.regplot(x="gross", y="budget", data=df1, scatter_kws={'color':'orange'},line_kws={'color':'blue'}, marker='*')
#       6
#
# ~\anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~\anaconda3\lib\site-packages\seaborn\regression.py in regplot(x, y, data, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, seed, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, dropna, x_jitter, y_jitter, label, color, marker, scatter_kws, line_kws, ax)
#     861     scatter_kws["marker"] = marker
# ...

# %%
# Will show correlation between the numerical columns only
# Different correlation methods: Pearson (default), Kendall, Spearman
df.corr()
# Out:
#              year     score     votes    budget     gross   runtime
# year     1.000000  0.097995  0.222945  0.309212  0.257486  0.120811
# score    0.097995  1.000000  0.409182  0.055665  0.186258  0.399451
# votes    0.222945  0.409182  1.000000  0.486862  0.630757  0.309212
# budget   0.309212  0.055665  0.486862  1.000000  0.748719  0.269510
# gross    0.257486  0.186258  0.630757  0.748719  1.000000  0.245216
# runtime  0.120811  0.399451  0.309212  0.269510  0.245216  1.000000

# %%
df.corr(method='pearson')  # pearson by default
# Out:
#              year     score     votes    budget     gross   runtime
# year     1.000000  0.097995  0.222945  0.309212  0.257486  0.120811
# score    0.097995  1.000000  0.409182  0.055665  0.186258  0.399451
# votes    0.222945  0.409182  1.000000  0.486862  0.630757  0.309212
# budget   0.309212  0.055665  0.486862  1.000000  0.748719  0.269510
# gross    0.257486  0.186258  0.630757  0.748719  1.000000  0.245216
# runtime  0.120811  0.399451  0.309212  0.269510  0.245216  1.000000

# %%
df.corr(method='kendall')
# Out:
#              year     score     votes    budget     gross   runtime
# year     1.000000  0.067652  0.331465  0.209304  0.200618  0.097184
# score    0.067652  1.000000  0.300115 -0.005194  0.086046  0.283611
# votes    0.331465  0.300115  1.000000  0.439902  0.548899  0.198240
# budget   0.209304 -0.005194  0.439902  1.000000  0.536640  0.176016
# gross    0.200618  0.086046  0.548899  0.536640  1.000000  0.168933
# runtime  0.097184  0.283611  0.198240  0.176016  0.168933  1.000000

# %%
df.corr(method='spearman')
# Out:
#              year     score     votes    budget     gross   runtime
# year     1.000000  0.099045  0.469829  0.291152  0.293084  0.142977
# score    0.099045  1.000000  0.428138 -0.007500  0.126116  0.399857
# votes    0.469829  0.428138  1.000000  0.604627  0.742050  0.290159
# budget   0.291152 -0.007500  0.604627  1.000000  0.711854  0.246748
# gross    0.293084  0.126116  0.742050  0.711854  1.000000  0.246243
# runtime  0.142977  0.399857  0.290159  0.246748  0.246243  1.000000

# %%
# Heatmap
plt.figure(figsize=(10,6))
plt.title('Correlation Matrix')
plt.xlabel('Movie Features')
plt.ylabel('Movie Features')
sns.heatmap(df1.corr(),annot=True)
# Out:
# <AxesSubplot:title={'center':'Correlation Matrix'}>

# %%
# Numeralise the columns - for categorisation of columns (# NOT WORKING)
df_numerised = df1

for col_name in df_numerised.columns:
    if (df_numerised(col_name).dtype == 'object'):
        df_numerised(col_name)=df_numerised(col_name).astype('category')
        df_numerised(col_name)=df_numerised(col_name).cat.codes   # Generate random category codes
# Out:
#   File "C:\Users\soura\AppData\Local\Temp\ipykernel_30564\1084955332.py", line 6
#     df_numerised(col_name)=df_numerised(col_name).astype('category')
#     ^
# SyntaxError: cannot assign to function call

# %%
# Using factorize - this assigns a random numeric value for each unique categorical value

df1.apply(lambda x: x.factorize()[0]).corr()
# Out:
#                   name    rating     genre      year  released     score  \
# name          1.000000  0.143938  0.036367  0.965761  0.959855 -0.046733
# rating        0.143938  1.000000 -0.086723  0.156713  0.146125  0.012595
# genre         0.036367 -0.086723  1.000000  0.037184  0.035980 -0.002437
# year          0.965761  0.156713  0.037184  1.000000  0.994020 -0.044981
# released      0.959855  0.146125  0.035980  0.994020  1.000000 -0.045722
# score        -0.046733  0.012595 -0.002437 -0.044981 -0.045722  1.000000
# votes         0.287776  0.099972  0.023285  0.312401  0.300098 -0.009749
# director      0.745905  0.085520  0.047288  0.770497  0.771360 -0.022687
# writer        0.805211  0.103623  0.033688  0.824770  0.820051 -0.034685
# star          0.731565  0.093116  0.038649  0.756400  0.755467 -0.009896
# country       0.142828  0.000494 -0.015795  0.140216  0.148111  0.023097
# budget        0.275691  0.193229  0.069445  0.298022  0.283644 -0.011749
# ...

# %%
corr_mat = df1.apply(lambda x: x.factorize()[0]).corr(method='pearson')
plt.figure(figsize=(12,7))
plt.title('Correlation Matrix')
plt.xlabel('Movie Features')
plt.ylabel('Movie Features')
sns.heatmap(corr_mat,annot=True)
plt.tight_layout()

# %%
# plt.figure(figsize=(12,7))
# sns.displot(x=df1['director'],y=df1['gross'], bins=1000)
# plt.tight_layout()

# %%
# Unstacking to check the correlation better
corr_mat= df1.corr()
corr_mat.unstack()
# Out:
# year     year       1.000000
#          score      0.097995
#          votes      0.222945
#          budget     0.309212
#          gross      0.257486
#          runtime    0.120811
# score    year       0.097995
#          score      1.000000
#          votes      0.409182
#          budget     0.055665
#          gross      0.186258
#          runtime    0.399451
# votes    year       0.222945
#          score      0.409182
#          votes      1.000000
#          budget     0.486862
#          gross      0.630757
#          runtime    0.309212
# budget   year       0.309212
#          score      0.055665
#          votes      0.486862
#          budget     1.000000
#          gross      0.748719
#          runtime    0.269510
# gross    year       0.257486
#          score      0.186258
#          votes      0.630757
#          budget     0.748719
#          gross      1.000000
#          runtime    0.245216
# runtime  year       0.120811
#          score      0.399451
# ...

# %%
# We find that 'gross' is highly correlated to: name, year, director, writer, star, year_correct

# %%
corr_pairs = corr_mat.unstack().sort_values()
corr_pairs
# Out:
# budget   score      0.055665
# score    budget     0.055665
# year     score      0.097995
# score    year       0.097995
# runtime  year       0.120811
# year     runtime    0.120811
# gross    score      0.186258
# score    gross      0.186258
# year     votes      0.222945
# votes    year       0.222945
# gross    runtime    0.245216
# runtime  gross      0.245216
# gross    year       0.257486
# year     gross      0.257486
# runtime  budget     0.269510
# budget   runtime    0.269510
# year     budget     0.309212
# budget   year       0.309212
# votes    runtime    0.309212
# runtime  votes      0.309212
#          score      0.399451
# score    runtime    0.399451
# votes    score      0.409182
# score    votes      0.409182
# votes    budget     0.486862
# budget   votes      0.486862
# gross    votes      0.630757
# votes    gross      0.630757
# budget   gross      0.748719
# gross    budget     0.748719
# year     year       1.000000
# budget   budget     1.000000
# ...

# %%
high_corr = corr_pairs[(corr_pairs.values) > 0.5]
high_corr
# Out:
# gross    votes      0.630757
# votes    gross      0.630757
# budget   gross      0.748719
# gross    budget     0.748719
# year     year       1.000000
# budget   budget     1.000000
# votes    votes      1.000000
# score    score      1.000000
# gross    gross      1.000000
# runtime  runtime    1.000000
# dtype: float64

# %%
# Which shows that gross earnings and budget have the highest correlation
